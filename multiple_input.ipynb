# %%
from typing import TypedDict, List

from langgraph.graph import StateGraph

# %%
class AgentState(TypedDict):

    values: List[int]

    name: str
    
    result: str

# %%
def process_values(state: AgentState) -> AgentState:

    """This function handles multiple different inputs and processes them"""

    print(state)

    state["result"] = f"Hi there {state["name"]}! Your answer is = {sum(state["values"])}"
    
    print(state)

    return state

# %%
graph = StateGraph(AgentState)

graph.add_node("processor", process_values)

graph.set_entry_point("processor") 

graph.set_finish_point("processor") 

app = graph.compile()

# %%
from IPython.display import Image, display

display(Image(app.get_graph().draw_mermaid_png()))

# %%
answers = app.invoke({"values": [1, 2, 3, 4], "name": "Mohit"})
# Out:
# {'values': [1, 2, 3, 4], 'name': 'Mohit'}
# {'values': [1, 2, 3, 4], 'name': 'Mohit', 'result': 'Hi there Mohit! Your answer is = 10'}

# %%
answers["result"]
# Out:
# 'Hi there Mohit! Your answer is = 10'
